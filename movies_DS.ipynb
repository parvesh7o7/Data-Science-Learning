# %% [markdown]
# <a href="https://colab.research.google.com/github/parvesh7o7/Data-Science-Learning/blob/main/movies_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# http://www.omdbapi.com/?i=tt3896198&apikey=4a4589fe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies_data = pd.read_csv('bollywood_box_clean.csv')

# %%
movies_data.head()
# Out:
#                            movie_name  movie_opening  movie_weekend  \
# 0                      Angrezi Medium           4.03           9.03
# 1                            Baaghi 3          17.50          53.83
# 2                             Thappad           3.07          14.66
# 3         Shubh Mangal Zyada Saavdhan           9.55          32.66
# 4  Bhoot: Part One - The Haunted Ship           5.10          16.36
#
#    movie_firstweek  movie_total  movie_total_worldwide      movie_genre  \
# 0             9.36         9.36                  13.50    Drama, Comedy
# 1            90.67        93.37                 137.00           Action
# 2            22.79        30.61                  44.50    Drama, Social
# 3            44.84        62.78                  86.39  Comedy, Romance
# 4            24.18        31.97                  40.94           Horror
#
#        movie_director        release_date  release_day release_month  \
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   movie_name             130 non-null    object
#  1   movie_opening          130 non-null    float64
#  2   movie_weekend          130 non-null    float64
#  3   movie_firstweek        130 non-null    float64
#  4   movie_total            130 non-null    float64
#  5   movie_total_worldwide  130 non-null    float64
#  6   movie_genre            129 non-null    object
#  7   movie_director         130 non-null    object
#  8   release_date           130 non-null    object
#  9   release_day            130 non-null    int64
#  10  release_month          130 non-null    object
#  11  release_year           130 non-null    int64
#  12  runtime                130 non-null    int64
#  13  producer               129 non-null    object
# ...

# %%
movies_data[movies_data['movie_genre'].isnull()]
# Out:
#    movie_name  movie_opening  movie_weekend  movie_firstweek  movie_total  \
# 83       Gold          25.25           71.3             89.3       107.37
#
#     movie_total_worldwide movie_genre movie_director      release_date  \
# 83                  149.5         NaN    Reema Kagti  15 August, 2018
#
#     release_day release_month  release_year  runtime  \
# 83           15           Aug          2018      153
#
#                             producer                banner  \
# 83   Ritesh Sidhwani , Farhan Akhtar   Excel Entertainment
#
#                                      actors  \
# 83   Akshay Kumar , Mouni Roy, Kunal Kapoor
#
#                                         movie_details
# 83  Set in 1948, the historic story of India's fir...

# %%
movies_data[movies_data['movie_genre'].isnull()]
# Out:
#    movie_name  movie_opening  movie_weekend  movie_firstweek  movie_total  \
# 83       Gold          25.25           71.3             89.3       107.37
#
#     movie_total_worldwide movie_genre movie_director      release_date  \
# 83                  149.5         NaN    Reema Kagti  15 August, 2018
#
#     release_day release_month  release_year  runtime  \
# 83           15           Aug          2018      153
#
#                             producer                banner  \
# 83   Ritesh Sidhwani , Farhan Akhtar   Excel Entertainment
#
#                                      actors  \
# 83   Akshay Kumar , Mouni Roy, Kunal Kapoor
#
#                                         movie_details
# 83  Set in 1948, the historic story of India's fir...

# %% [markdown]
# ### **DROPPING THE NULL ROW OF THE MOVIE_GENRE COLUMN**
#
# ---

# %%
movies_data.dropna(subset=['movie_genre'], inplace=True)

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129 entries, 0 to 129
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   movie_name             129 non-null    object
#  1   movie_opening          129 non-null    float64
#  2   movie_weekend          129 non-null    float64
#  3   movie_firstweek        129 non-null    float64
#  4   movie_total            129 non-null    float64
#  5   movie_total_worldwide  129 non-null    float64
#  6   movie_genre            129 non-null    object
#  7   movie_director         129 non-null    object
#  8   release_date           129 non-null    object
#  9   release_day            129 non-null    int64
#  10  release_month          129 non-null    object
#  11  release_year           129 non-null    int64
#  12  runtime                129 non-null    int64
#  13  producer               128 non-null    object
# ...

# %% [markdown]
# ### **UNIQUE MOVIE_GENRE AVAILABLE IN DATA**
#
# ---

# %%
unique_genres = movies_data['movie_genre'].unique()
print("//////Movie Genre///////\n")
print(unique_genres, "\n")
print("Total Genre: ", len(unique_genres))
# Out:
# //////Movie Genre///////
#
# ['Drama, Comedy' 'Action' 'Drama, Social' 'Comedy, Romance' 'Horror'
#  'Romance' 'Romance, Action' 'Drama, Romance' 'Comedy, Drama'
#  'Sports, Drama' 'Dance' 'Historical, Action' 'Drama' 'Comedy'
#  'Crime, Action, Thriller' 'Historical, war, Action'
#  'Action, Romance, Drama' 'Biographical' 'Action, Thriller'
#  'Romance, Drama' 'Action, Crime, Thriller' 'Action, Romance, Comedy'
#  'Comedy, Crime, Thriller' 'Crime, Thriller' 'Thriller' 'Drama, Period'
#  'Drama, Romance, Action' 'Period, Drama, Romance'
#  'Drama, Period, Mystery, Thriller' 'Spy, Action, Thriller'
#  'Period, Action, war' 'Crime, Action' 'Musical' 'Action, Comedy, Drama'
#  'Action, Drama' 'Sci-fi, Action' 'Comedy, Action' 'Drama, Thriller'
#  'Action, Adventure' 'Crime, Drama' 'Horror, Thriller'
#  'Thriller, Suspense, Crime' 'Comedy, Horror' 'Biographical, Sports'
#  'Drama, Social, Thriller' 'Action, Romance' 'Social'
# ...
